# %%
import pandas as pd
from pandas_datareader import data as web
import plotly.graph_objects as go

ticker = 'BTC-USD'
 
df = web.DataReader(name = ticker, data_source = 'yahoo', start = '01-01-2019')

print(df)

trace1 = {
    'x': df.index,
    'open': df.Open,
    'close': df.Close,
    'high': df.High,
    'low': df.Low,
    #'volume': df.Volume,
    'type': 'candlestick',
    'name': ticker,
    'showlegend': True
}

avg_30 = df.Close.rolling(window=30, min_periods=1).mean()
avg_50 = df.Close.rolling(window=50, min_periods=1).mean()

trace2 = {
    'x': df.index,
    'y': avg_30,
    'type': 'scatter',
    'mode': 'lines',
    'line': {
        'width': 1,
        'color': 'blue'
            },
    'name': 'Moving Average of 30 periods'
}

trace3 = {
    'x': df.index,
    'y': avg_50,
    'type': 'scatter',
    'mode': 'lines',
    'line': {
        'width': 1,
        'color': 'red'
    },
    'name': 'Moving Average of 50 periods'
}

data = [trace1, trace2, trace3]

layout = go.Layout({
    'title': {
        'text': 'BitCoin(' + ticker + ') Moving Averages',
        'font': {
            'size': 15
        }
    }
})

fig = go.Figure(data)
fig.add_trace(go.Bar(x = df.index, y = df.Volume), secondary_y = False)
fig.show()
# Out:
#                     High           Low          Open         Close  \
# Date
# 2019-01-01   3850.913818   3707.231201   3746.713379   3843.520020
# 2019-01-02   3947.981201   3817.409424   3849.216309   3943.409424
# 2019-01-03   3935.685059   3826.222900   3931.048584   3836.741211
# 2019-01-04   3865.934570   3783.853760   3832.040039   3857.717529
# 2019-01-05   3904.903076   3836.900146   3851.973877   3845.194580
# ...                  ...           ...           ...           ...
# 2021-12-22  49544.796875  48450.941406  48937.097656  48628.511719
# 2021-12-23  51332.339844  48065.835938  48626.343750  50784.539062
# 2021-12-24  51814.027344  50514.496094  50806.050781  50822.195312
# 2021-12-25  51176.597656  50236.707031  50854.917969  50429.859375
# 2021-12-26  50941.574219  49623.105469  50450.296875  50815.875000
#
#                  Volume     Adj Close
# Date
# 2019-01-01   4324200990   3843.520020
# 2019-01-02   5244856836   3943.409424
# 2019-01-03   4530215219   3836.741211
# 2019-01-04   4847965467   3857.717529
# 2019-01-05   5137609824   3845.194580
# ...                 ...           ...
# 2021-12-22  24447979559  48628.511719
# 2021-12-23  28223878108  50784.539062
# 2021-12-24  24367912228  50822.195312
# 2021-12-25  19030650914  50429.859375
# 2021-12-26  20978956288  50815.875000
#
# [1091 rows x 6 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/plotly/basedatatypes.py in _validate_get_grid_ref(self)
#    2328             if grid_ref is None:
# -> 2329                 raise AttributeError("_grid_ref")
#    2330         except AttributeError:
#
# AttributeError: _grid_ref
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-20-3e77dad7f92b> in <module>
#      60
#      61 fig = go.Figure(data)
# ---> 62 fig.add_trace(go.Bar(x = df.index, y = df.Volume), secondary_y = False)
#      63 fig.show()
#
# /usr/local/lib/python3.8/dist-packages/plotly/basedatatypes.py in add_trace(self, trace, row, col, secondary_y, exclude_empty_subplots)
#    2097             return self
#    2098
# -> 2099         return self.add_traces(
#    2100             data=[trace],
#    2101             rows=[row] if row is not None else None,
#
# /usr/local/lib/python3.8/dist-packages/plotly/basedatatypes.py in add_traces(self, data, rows, cols, secondary_ys, exclude_empty_subplots)
#    2227         if rows is not None:
#    2228             for trace, row, col, secondary_y in zip(data, rows, cols, secondary_ys):
# -> 2229                 self._set_trace_grid_position(trace, row, col, secondary_y)
#    2230
#    2231         if exclude_empty_subplots:
#
# /usr/local/lib/python3.8/dist-packages/plotly/basedatatypes.py in _set_trace_grid_position(self, trace, row, col, secondary_y)
#    2318         from plotly.subplots import _set_trace_grid_reference
#    2319
# -> 2320         grid_ref = self._validate_get_grid_ref()
#    2321         return _set_trace_grid_reference(
#    2322             trace, self.layout, grid_ref, row, col, secondary_y
#
# /usr/local/lib/python3.8/dist-packages/plotly/basedatatypes.py in _validate_get_grid_ref(self)
#    2329                 raise AttributeError("_grid_ref")
#    2330         except AttributeError:
# -> 2331             raise Exception(
#    2332                 "In order to reference traces by row and column, "
#    2333                 "you must first use "
#
# Exception: In order to reference traces by row and column, you must first use plotly.tools.make_subplots to create the figure with a subplot grid.
